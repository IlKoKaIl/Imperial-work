# %%
from astropy.table import Table

t = Table.read("master.dat.gz", format="ascii")
t
# Out:
# <Table length=131178>
#  col1        col2           col3       col4   ...  col29    col30    col31
# int64      float64        float64    float64  ...  str11     str8    str11
# ------ --------------- ------------- -------- ... -------- -------- --------
# 191856 149.39724661368 1.69517720906 0.100686 ...      ---      ---      ---
# 232993 149.39732087474 1.69960173064 0.020553 ...      ---      ---      ---
# -21735 149.39740775945 1.89131811366 0.320046 ... 0.571956 1.045774 1.191963
# 712169 149.39774455396 1.77245846672 0.005772 ...      ---      ---      ---
#  -4568      149.397959      1.802273 0.571927 ... 0.562763 1.299591 1.416205
# 159954 149.39807136708 1.80925466255 0.000721 ...      ---      ---      ---
# 267926 149.39820217758  1.8208433743 0.013968 ...      ---      ---      ---
# 242474 149.39820431386 1.70080513077 0.002077 ...      ---      ---      ---
# 385996 149.39822074369 1.73762747455 0.355877 ...      ---      ---      ---
# ...
